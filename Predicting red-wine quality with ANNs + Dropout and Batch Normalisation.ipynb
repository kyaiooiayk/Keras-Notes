# %% [markdown]
# # Introduction

# %% [markdown]
# <div class="alert alert-warning">
# <font color=black>
#
# **What?** Predicting red-wine quality with ANNs + Dropout and Batch Normalisation
#
# </font>
# </div>

# %% [markdown]
# # Theoretical recall: dropout

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - Dropout layer can help correct overfitting which is caused by the network **learning spurious patterns** in the training data.
# - To recognize these spurious patterns a network will often rely on very a specific combinations of weight, a kind of "conspiracy" of weights. Being so specific, they tend to be fragile: remove one and the conspiracy falls apart.
# - This is the idea behind dropout. To break up these conspiracies, we randomly drop out some fraction of a layer's input units every step of training, making it much harder for the network to learn those spurious patterns in the training data.
# - Instead, it has to search for broad, general patterns, whose weight patterns tend to be more robust.
# - You could also think about dropout as creating a kind of ensemble of networks.
# - The predictions will no longer be made by one big network, but instead by a committee of smaller networks.
# - Individuals in the committee tend to make different kinds of mistakes, but be right at the same time, making the committee as a whole better than any individual.
# - If you're familiar with random forests as an ensemble of decision trees, it's the same idea.
#
# <br></font>
# </div>

# %% [markdown]
# # Theoretical recall: batch normalisation

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - Batchnorm can help correct training that is slow or unstable.
# - Sometimes also help prediction performance.
# - SGD will shift the network weights in proportion to how large an activation the data produces. Features that tend to produce activations of very different sizes can make for unstable training behavior.
# - If it's good to normalize the data before it goes into the network, maybe also normalizing inside the network would be better! In fact, we have a special kind of layer that can do this, the batch normalization layer. A batch normalization layer looks at each batch as it comes in, first normalizing the batch with its own mean and standard deviation, and then also putting the data on a new scale with two trainable rescaling parameters. Batchnorm, in effect, performs a kind of coordinated rescaling of its inputs.
#
# <br></font>
# </div>

# %% [markdown]
# # Import modules

# %%
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib as mpl
from tensorflow import keras
from tensorflow.keras import layers, callbacks

rcParams['figure.figsize'] = 17, 8
rcParams['font.size'] = 20

# %% [markdown]
# # Import dataset

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - We'll use the *Red Wine Quality* dataset.
# - This dataset consists of physiochemical measurements from about 1600 Portuguese red wines.
# - Also included is a quality rating for each wine from blind taste-tests.
# - How well can we predict a wine's perceived quality from these measurements?
#
# <br></font>
# </div>

# %%
red_wine = pd.read_csv('../DATASETS/winequality-red.csv')

# Create training and validation splits
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)
display(df_train.head(4))

# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109           10.8             0.470         0.43            2.10      0.171
# 1032            8.1             0.820         0.00            4.10      0.095
# 1002            9.1             0.290         0.33            2.05      0.063
# 487            10.2             0.645         0.36            1.80      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1109                 27.0                  66.0  0.99820  3.17       0.76
# 1032                  5.0                  14.0  0.99854  3.36       0.53
# 1002                 13.0                  27.0  0.99516  3.26       0.84
# 487                   5.0                  14.0  0.99820  3.17       0.42
#
#       alcohol  quality
# 1109     10.8        6
# 1032      9.6        5
# 1002     11.7        7
# 487      10.0        6

# %%
print(X_train.shape)
# Out:
# (1119, 11)

# %% [markdown]
# # Building the ANNs

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - We've chosen a three-layer network with over 1500 neurons.
# - This network should be capable of learning fairly complex relationships in the data.
#
# <br></font>
# </div>

# %%
model = keras.Sequential([
    layers.Dense(1024, activation = 'relu', input_shape = [11]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation = 'relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation = 'relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)

# %%
early_stopping = callbacks.EarlyStopping(
    # Minimium amount of change to count as an improvement
    min_delta=0.001, 
    # How many epochs to wait before stopping
    patience = 50, 
    restore_best_weights=True,
)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - We'll feed the optimizer 256 rows of the training data at a time (the batch_size) and to do that 500 times all the way through the dataset (the epochs).
# - Since we are using early atopping, we'll probably not reach the 500th epoch.
#
# <br></font>
# </div>

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size = 256,
    epochs = 500,
    callbacks = [early_stopping],
    verbose = 1,  
)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 1s 76ms/step - loss: 1.2765 - val_loss: 0.3911
# Epoch 2/500
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2757 - val_loss: 0.1932
# Epoch 3/500
# 5/5 [==============================] - 0s 45ms/step - loss: 1.1616 - val_loss: 0.1520
# Epoch 4/500
# 5/5 [==============================] - 0s 45ms/step - loss: 1.0686 - val_loss: 0.1429
# Epoch 5/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.9524 - val_loss: 0.1704
# Epoch 6/500
# 5/5 [==============================] - 0s 42ms/step - loss: 1.0223 - val_loss: 0.1311
# Epoch 7/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.8456 - val_loss: 0.1536
# Epoch 8/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7785 - val_loss: 0.1336
# Epoch 9/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.7249 - val_loss: 0.1441
# Epoch 10/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6680 - val_loss: 0.1429
# Epoch 11/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6498 - val_loss: 0.1436
# Epoch 12/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.6052 - val_loss: 0.1437
# Epoch 13/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5643 - val_loss: 0.1405
# Epoch 14/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5243 - val_loss: 0.1423
# Epoch 15/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4866 - val_loss: 0.1394
# Epoch 16/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4742 - val_loss: 0.1383
# Epoch 17/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.4619 - val_loss: 0.1315
# Epoch 18/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.4127 - val_loss: 0.1401
# Epoch 19/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.4050 - val_loss: 0.1389
# Epoch 20/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3920 - val_loss: 0.1398
# Epoch 21/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3722 - val_loss: 0.1363
# Epoch 22/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3421 - val_loss: 0.1377
# Epoch 23/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3225 - val_loss: 0.1451
# Epoch 24/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3164 - val_loss: 0.1330
# Epoch 25/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2971 - val_loss: 0.1331
# Epoch 26/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2941 - val_loss: 0.1345
# Epoch 27/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2660 - val_loss: 0.1344
# Epoch 28/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2788 - val_loss: 0.1368
# Epoch 29/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2481 - val_loss: 0.1388
# Epoch 30/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2534 - val_loss: 0.1335
# Epoch 31/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2293 - val_loss: 0.1351
# Epoch 32/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2227 - val_loss: 0.1342
# Epoch 33/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2272 - val_loss: 0.1586
# Epoch 34/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2269 - val_loss: 0.1299
# Epoch 35/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2146 - val_loss: 0.1366
# Epoch 36/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2126 - val_loss: 0.1351
# Epoch 37/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1940 - val_loss: 0.1349
# Epoch 38/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1966 - val_loss: 0.1356
# Epoch 39/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1859 - val_loss: 0.1388
# Epoch 40/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1896 - val_loss: 0.1367
# Epoch 41/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1712 - val_loss: 0.1305
# Epoch 42/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1803 - val_loss: 0.1408
# Epoch 43/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1783 - val_loss: 0.1351
# Epoch 44/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1720 - val_loss: 0.1343
# Epoch 45/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1700 - val_loss: 0.1381
# Epoch 46/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1699 - val_loss: 0.1392
# Epoch 47/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1679 - val_loss: 0.1404
# Epoch 48/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1647 - val_loss: 0.1310
# Epoch 49/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1640 - val_loss: 0.1356
# Epoch 50/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1588 - val_loss: 0.1384
# Epoch 51/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1509 - val_loss: 0.1340
# Epoch 52/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1425 - val_loss: 0.1358
# Epoch 53/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1461 - val_loss: 0.1339
# Epoch 54/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1468 - val_loss: 0.1394
# Epoch 55/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1577 - val_loss: 0.1362
# Epoch 56/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1528 - val_loss: 0.1308
# Epoch 57/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1536 - val_loss: 0.1380
# Epoch 58/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1383 - val_loss: 0.1320
# Epoch 59/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1436 - val_loss: 0.1275
# Epoch 60/500
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1450 - val_loss: 0.1330
# Epoch 61/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1398 - val_loss: 0.1288
# Epoch 62/500
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1364 - val_loss: 0.1259
# Epoch 63/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1340 - val_loss: 0.1316
# Epoch 64/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1419 - val_loss: 0.1278
# Epoch 65/500
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1357 - val_loss: 0.1270
# Epoch 66/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1393 - val_loss: 0.1282
# Epoch 67/500
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1331 - val_loss: 0.1250
# Epoch 68/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1335 - val_loss: 0.1344
# Epoch 69/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1341 - val_loss: 0.1277
# Epoch 70/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1249 - val_loss: 0.1257
# Epoch 71/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1325 - val_loss: 0.1253
# Epoch 72/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1251 - val_loss: 0.1249
# Epoch 73/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1212 - val_loss: 0.1256
# Epoch 74/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1231 - val_loss: 0.1216
# Epoch 75/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1251 - val_loss: 0.1238
# Epoch 76/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1228 - val_loss: 0.1242
# Epoch 77/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1200 - val_loss: 0.1205
# Epoch 78/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1268 - val_loss: 0.1193
# Epoch 79/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1193 - val_loss: 0.1214
# Epoch 80/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1227 - val_loss: 0.1198
# Epoch 81/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1178 - val_loss: 0.1175
# Epoch 82/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1129 - val_loss: 0.1167
# Epoch 83/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1158 - val_loss: 0.1188
# Epoch 84/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1191 - val_loss: 0.1164
# Epoch 85/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1161 - val_loss: 0.1167
# Epoch 86/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1164 - val_loss: 0.1168
# Epoch 87/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1221 - val_loss: 0.1169
# Epoch 88/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1169 - val_loss: 0.1160
# Epoch 89/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1154 - val_loss: 0.1137
# Epoch 90/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1204 - val_loss: 0.1127
# Epoch 91/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1165 - val_loss: 0.1144
# Epoch 92/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1189 - val_loss: 0.1128
# Epoch 93/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1130 - val_loss: 0.1099
# Epoch 94/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1151 - val_loss: 0.1149
# Epoch 95/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1117 - val_loss: 0.1101
# Epoch 96/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1113 - val_loss: 0.1114
# Epoch 97/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1087 - val_loss: 0.1129
# Epoch 98/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1098 - val_loss: 0.1056
# Epoch 99/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1137 - val_loss: 0.1076
# Epoch 100/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1128 - val_loss: 0.1072
# Epoch 101/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1135 - val_loss: 0.1134
# Epoch 102/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1122 - val_loss: 0.1056
# Epoch 103/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1100 - val_loss: 0.1087
# Epoch 104/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1124 - val_loss: 0.1082
# Epoch 105/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1137 - val_loss: 0.1064
# Epoch 106/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1119 - val_loss: 0.1106
# Epoch 107/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1258 - val_loss: 0.1240
# Epoch 108/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1165 - val_loss: 0.1030
# Epoch 109/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1135 - val_loss: 0.1082
# Epoch 110/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1137 - val_loss: 0.1106
# Epoch 111/500
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1133 - val_loss: 0.1031
# Epoch 112/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1100 - val_loss: 0.1057
# Epoch 113/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1068 - val_loss: 0.1021
# Epoch 114/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1066 - val_loss: 0.1032
# Epoch 115/500
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1075 - val_loss: 0.1001
# Epoch 116/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1050 - val_loss: 0.1062
# Epoch 117/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1096 - val_loss: 0.0984
# Epoch 118/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1099 - val_loss: 0.1010
# Epoch 119/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1107 - val_loss: 0.1126
# Epoch 120/500
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1097 - val_loss: 0.1001
# Epoch 121/500
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1051 - val_loss: 0.1005
# Epoch 122/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1070 - val_loss: 0.1008
# Epoch 123/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1026 - val_loss: 0.1048
# Epoch 124/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1066 - val_loss: 0.0991
# Epoch 125/500
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1115 - val_loss: 0.1030
# Epoch 126/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1099 - val_loss: 0.0999
# Epoch 127/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1064 - val_loss: 0.1172
# Epoch 128/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1183 - val_loss: 0.1008
# Epoch 129/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1147 - val_loss: 0.1085
# Epoch 130/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1123 - val_loss: 0.1051
# Epoch 131/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1102 - val_loss: 0.1004
# Epoch 132/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1040 - val_loss: 0.1054
# Epoch 133/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1060 - val_loss: 0.0968
# Epoch 134/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1055 - val_loss: 0.1026
# Epoch 135/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1028 - val_loss: 0.0980
# Epoch 136/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1029 - val_loss: 0.1040
# Epoch 137/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1071 - val_loss: 0.0970
# Epoch 138/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1043 - val_loss: 0.0982
# Epoch 139/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1074 - val_loss: 0.1015
# Epoch 140/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1019 - val_loss: 0.1092
# Epoch 141/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1073 - val_loss: 0.0980
# Epoch 142/500
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1045 - val_loss: 0.1046
# Epoch 143/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1055 - val_loss: 0.0944
# Epoch 144/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1048 - val_loss: 0.0961
# Epoch 145/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1008 - val_loss: 0.0931
# Epoch 146/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1014 - val_loss: 0.1087
# Epoch 147/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1098 - val_loss: 0.1096
# Epoch 148/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1064 - val_loss: 0.1000
# Epoch 149/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1071 - val_loss: 0.0982
# Epoch 150/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1093 - val_loss: 0.1052
# Epoch 151/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1086 - val_loss: 0.1038
# Epoch 152/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1043 - val_loss: 0.0966
# Epoch 153/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1007 - val_loss: 0.0989
# Epoch 154/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1020 - val_loss: 0.0982
# Epoch 155/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1058 - val_loss: 0.0969
# Epoch 156/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1059 - val_loss: 0.0991
# Epoch 157/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0992 - val_loss: 0.1088
# Epoch 158/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1088 - val_loss: 0.0946
# Epoch 159/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1033 - val_loss: 0.0981
# Epoch 160/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0999 - val_loss: 0.0953
# Epoch 161/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1001 - val_loss: 0.0977
# Epoch 162/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1043 - val_loss: 0.1075
# Epoch 163/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1113 - val_loss: 0.1003
# Epoch 164/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1059 - val_loss: 0.0982
# Epoch 165/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0984 - val_loss: 0.0973
# Epoch 166/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0967 - val_loss: 0.0936
# Epoch 167/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0959 - val_loss: 0.0962
# Epoch 168/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0967 - val_loss: 0.0956
# Epoch 169/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0995 - val_loss: 0.1049
# Epoch 170/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1050 - val_loss: 0.0932
# Epoch 171/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1020 - val_loss: 0.1019
# Epoch 172/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0998 - val_loss: 0.0940
# Epoch 173/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0964 - val_loss: 0.0917
# Epoch 174/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0984 - val_loss: 0.0969
# Epoch 175/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1060 - val_loss: 0.0983
# Epoch 176/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1035 - val_loss: 0.1046
# Epoch 177/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1084 - val_loss: 0.0927
# Epoch 178/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1037 - val_loss: 0.1009
# Epoch 179/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1038 - val_loss: 0.0912
# Epoch 180/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0994 - val_loss: 0.0950
# Epoch 181/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0912 - val_loss: 0.0934
# Epoch 182/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0980 - val_loss: 0.0954
# Epoch 183/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0966 - val_loss: 0.0965
# Epoch 184/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0960 - val_loss: 0.0968
# Epoch 185/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0976 - val_loss: 0.0986
# Epoch 186/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0990 - val_loss: 0.1006
# Epoch 187/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1017 - val_loss: 0.0965
# Epoch 188/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0985 - val_loss: 0.0977
# Epoch 189/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1003 - val_loss: 0.0952
# Epoch 190/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0971 - val_loss: 0.0949
# Epoch 191/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0947 - val_loss: 0.0933
# Epoch 192/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0928 - val_loss: 0.1019
# Epoch 193/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0976 - val_loss: 0.1009
# Epoch 194/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1017 - val_loss: 0.1010
# Epoch 195/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1009 - val_loss: 0.1197
# Epoch 196/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1082 - val_loss: 0.1023
# Epoch 197/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1021 - val_loss: 0.0910
# Epoch 198/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0965 - val_loss: 0.0923
# Epoch 199/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0955 - val_loss: 0.1074
# Epoch 200/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0998 - val_loss: 0.1058
# Epoch 201/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1048 - val_loss: 0.0929
# Epoch 202/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0998 - val_loss: 0.1051
# Epoch 203/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1009 - val_loss: 0.0933
# Epoch 204/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0936 - val_loss: 0.0922
# Epoch 205/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0956 - val_loss: 0.1017
# Epoch 206/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0972 - val_loss: 0.0949
# Epoch 207/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0940 - val_loss: 0.0946
# Epoch 208/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0938 - val_loss: 0.0928
# Epoch 209/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0949 - val_loss: 0.0995
# Epoch 210/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1006 - val_loss: 0.1055
# Epoch 211/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1015 - val_loss: 0.1044
# Epoch 212/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1012 - val_loss: 0.0999
# Epoch 213/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1004 - val_loss: 0.0929
# Epoch 214/500
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0957 - val_loss: 0.0983
# Epoch 215/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1056 - val_loss: 0.1007
# Epoch 216/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1017 - val_loss: 0.1073
# Epoch 217/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1030 - val_loss: 0.1034
# Epoch 218/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1004 - val_loss: 0.1011
# Epoch 219/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0976 - val_loss: 0.1026
# Epoch 220/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0982 - val_loss: 0.1044
# Epoch 221/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0975 - val_loss: 0.0998
# Epoch 222/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0966 - val_loss: 0.0971
# Epoch 223/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0957 - val_loss: 0.0958

# %%
# Convert the training history to a dataframe and plot
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))
# Out:
# Minimum validation loss: 0.09100586920976639

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - Notice how the loss levels off as the epochs go by.
# - When the loss curve becomes horizontal like that, it means the model has learned all it can and there would be no reason continue for additional epochs.
# - Please note that if we did not use early stopping the model would have gone all the way to 500 probably overfitting.
#
# <br></font>
# </div>

# %% [markdown]
# # References

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color=black><br>
#
# - https://www.kaggle.com/ryanholbrook/stochastic-gradient-descent
# - https://www.kaggle.com/ryanholbrook/dropout-and-batch-normalization
#
# <br></font>
# </div>
